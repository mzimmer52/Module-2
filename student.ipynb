# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("kc_house_data.csv")
df.columns
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront       float64
# view             float64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement     object
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650     1.0         NaN   0.0  ...      7        1180
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 2         10000     1.0         0.0   0.0  ...      6         770
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.isna().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
import seaborn as sns 
fig, ax = plt.subplots(6,3, figsize = (10,15))
columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15']
ax = ax.flatten()
for axe, col in zip(ax, columns):
    sns.violinplot(x = col, data = df, ax = axe)
plt.tight_layout()
plt.show()

# %%
#Years since renovation, 0 corresponds to no renovation 
df["yr_renovated"] = df["yr_renovated"].fillna(0)
df["years_since_renovated"] = 0
df.loc[df["yr_renovated"] != 0, "years_since_renovated"] = df.loc[df["yr_renovated"] != 0, "date"].str.slice(-4).astype(int) - df.loc[df["yr_renovated"] != 0, "yr_renovated"]
df[df["years_since_renovated"] != 0]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192  12/9/2014   538000.0         3       2.25         2570
# 35     9547205180  6/13/2014   696000.0         3       2.50         2300
# 95     1483300570   9/8/2014   905000.0         4       2.50         3300
# 103    2450000295  10/7/2014  1090000.0         3       2.50         2920
# 125    4389200955   3/2/2015  1450000.0         4       2.75         2750
# ...           ...        ...        ...       ...        ...          ...
# 19602  6392000625  7/12/2014   451000.0         2       1.00          900
# 20041   126039256   9/4/2014   434900.0         3       2.00         1520
# 20428  4305600360  2/25/2015   500012.0         4       2.50         2400
# 20431  3319500628  2/12/2015   356999.0         3       1.50         1010
# 20946  1278000210  3/11/2015   110000.0         2       1.00          828
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 1          7242     2.0         0.0   0.0  ...        2170          400.0
# 35         3060     1.5         0.0   0.0  ...        1510          790.0
# 95        10250     1.0         0.0   0.0  ...        2390          910.0
# 103        8113     2.0         0.0   0.0  ...        2920            0.0
# 125       17789     1.5         0.0   0.0  ...        1980          770.0
# ...         ...     ...         ...   ...  ...         ...            ...
# 19602      6000     1.0         0.0   0.0  ...         900            0.0
# 20041      5040     2.0         0.0   0.0  ...        1520            0.0
# 20428      9612     1.0         0.0   0.0  ...        1230         1170.0
# 20431      1546     2.0         NaN   0.0  ...        1010            0.0
# 20946      4524     1.0         0.0   0.0  ...         828            0.0
#
#        yr_built yr_renovated  zipcode      lat     long  sqft_living15  \
# 1          1951       1991.0    98125  47.7210 -122.319           1690
# 35         1930       2002.0    98115  47.6827 -122.310           1590
# 95         1946       1991.0    98040  47.5873 -122.249           1950
# 103        1950       2010.0    98004  47.5814 -122.196           2370
# 125        1914       1992.0    98004  47.6141 -122.212           3060
# ...         ...          ...      ...      ...      ...            ...
# 19602      1944       2004.0    98115  47.6855 -122.289           1460
# 20041      1977       2006.0    98177  47.7770 -122.362           1860
# 20428      1962       2009.0    98059  47.4799 -122.127           2430
# 20431      1971       2014.0    98144  47.5998 -122.311           1010
# 20946      1968       2007.0    98001  47.2655 -122.244            828
#
#        sqft_lot15  years_since_renovated
# 1            7639                   23.0
# 35           3264                   12.0
# 95           6045                   23.0
# 103          8113                    4.0
# 125         11275                   23.0
# ...           ...                    ...
# 19602        4800                   10.0
# 20041        8710                    8.0
# 20428        5539                    6.0
# 20431        1517                    1.0
# 20946        5402                    8.0
#
# [676 rows x 22 columns]

# %%
plt.scatter(df["years_since_renovated"], df["price"])
#No real relationship

# %%
df.zipcode.unique()
# 98106 - $53,174 Median Family Income - Poorest zipcode
#98074 - $170,744 Median Family Income - Richest zipcode
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039])

# %%
#finding mean coordinates for poor and rich neighborhoods
poor_lat = df.loc[df["zipcode"] == 98106]["lat"].mean()
poor_long = df.loc[df["zipcode"] == 98106]["long"].mean()
rich_lat = df.loc[df["zipcode"] == 98074]["lat"].mean()
rich_long = df.loc[df["zipcode"] == 98074]["long"].mean()

# %%
#distance between each house and mean lat and long for poorest zipcode
import geopy.distance
coord_1 = (poor_lat, poor_long)
coords = list(zip(df.lat, df.long))
empty = []
for coord in coords:
    distance = geopy.distance.distance(coord_1, coord).km
    empty.append(abs(distance))
df["zip_distance_poor"] = empty

# %%
#distance between each house and mean lat and long for richest zipcode
coord_1 = (rich_lat, rich_long)
coords = list(zip(df.lat, df.long))
empty2 = []
for coord in coords:
    distance = geopy.distance.distance(coord_1, coord).km
    empty2.append(abs(distance))
df["zip_distance_rich"] = empty2

# %%
#scatter plot for distance from poorest zip code
plt.scatter(empty, df["price"]);
#No real relationship here

# %%
#scatter plot for distance from richest zip code
plt.scatter(empty2, df["price"]);
#No real relationship here

# %% [markdown]
# Should Zipcode be treated as a continuous or a categoical variable?

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'years_since_renovated',
#        'zip_distance_poor', 'zip_distance_rich'],
#       dtype='object')

# %% [markdown]
# sqft_lot and sqft_lot15 also highly correlated, drop sqft_lot 15 to avoid multicollinearity

# %%
fig, ax = plt.subplots(6, 4, figsize = (15,12))
for col, axe in zip(df.columns, ax.flatten()):
    axe.scatter(df[col], df['price'], label = col)
    axe.legend()
    plt.tight_layout()

# %%
included = ["bathrooms", "sqft_living", "zip_distance_rich"]

progress = df[included].corr().abs().stack().reset_index().sort_values(0, ascending=False)
progress['pairs'] = list(zip(progress.level_0, progress.level_1))

progress.set_index(['pairs'], inplace = True)

progress.drop(columns=['level_1', 'level_0'], inplace = True)

# cc for correlation coefficient
progress.columns = ['cc']

progress.drop_duplicates(inplace=True)

progress[(progress.cc>.5) & (progress.cc<1)]
# Out:
#                                 cc
# pairs
# (bathrooms, sqft_living)  0.755758

# %%
def normalize(feature):
    return (feature - feature.mean())/feature.std()

# %%
beds = pd.get_dummies(df["bedrooms"], "bedrooms", drop_first = True)
grades = pd.get_dummies(df["grade"], "grade", drop_first = True)
X = pd.concat([df[included], beds, grades], axis = 1)
X["add"] = X['bathrooms'] * X['sqft_living']

# %%
X.hist(figsize = (15,12));

# %%
#X['sqft_living'] = (X['sqft_living'] - X['sqft_living'].mean())/X['sqft_living'].std()
X['sqft_living'] = np.log(X.sqft_living)
X['sqft_living'].hist()

# %%
log_living = X['sqft_living']
scaled_sqft_living = (log_living - np.mean(log_living)) / np.sqrt(np.var(log_living))
scaled_sqft_living.hist();

# %%
import pylab 
import scipy.stats as stats

measurements = np.random.normal(loc = 20, scale = 5, size=100)   
stats.probplot(X['sqft_living'], dist="norm", plot=pylab)
pylab.show()

# %%
log_bathroom = np.log(X["bathrooms"])
scaled_bathrooms = (log_bathroom - np.mean(log_bathroom)) / np.sqrt(np.var(log_bathroom))
scaled_bathrooms.hist()

# %%
stats.probplot(np.log(X['bathrooms']), dist="norm", plot=pylab)
pylab.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
linreg = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X, (df["price"]))
linreg.fit(X_train, y_train)
y_train_hat = linreg.predict(X_train)
y_test_hat = linreg.predict(X_test)
r2_score(y_test, y_test_hat)
# Out:
# 0.658519141183699

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
crossvalidation = KFold(n_splits=5, shuffle=True)
score = np.mean(cross_val_score(linreg, X, df["price"] , scoring='r2', cv=crossvalidation))
score
# Out:
# 0.615427058474193

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations

interactions = []
crossvalidation = KFold(n_splits=5, shuffle=True, random_state=1)
feat_combinations = combinations(X.columns, 2)
baseline = 0.55
data = X
for i, (a, b) in enumerate(feat_combinations):
    data['interaction'] = data[a] * data[b]
    score = np.mean(cross_val_score(linreg, data, df["price"] , scoring='r2', cv=crossvalidation))
    if score > baseline:
        interactions.append((a, b, round(score,3)))
    
    if i % 50 == 0:
        print(i)
            
print('Top 3 interactions: %s' %sorted(interactions, key=lambda inter: inter[2], reverse=True)[:3])
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# Top 3 interactions: [('bedrooms_7', 'add', 0.624), ('bathrooms', 'bedrooms_7', 0.619), ('grade_13', 'add', 0.619)]

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(2)
X_poly_train = poly.fit_transform(X_train)
reg_poly = linreg.fit(X_poly_train, y_train)
X_poly_test = poly.transform(X_test)
y_prediction = reg_poly.predict(X_poly_test)
r2_score(y_test, y_prediction)
# Out:
# 0.5201789890014998

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations

interactions = []
crossvalidation = KFold(n_splits=5, shuffle=True, random_state=1)
feat_combinations = combinations(X.columns, 2)
baseline = 0.55
data = X
for i, (a, b) in enumerate(feat_combinations):
    data['interaction'] = data[a] * data[b]
    score = np.mean(cross_val_score(linreg, data, df["price"] , scoring='r2', cv=crossvalidation))
    if score > baseline:
        interactions.append((a, b, round(score,3)))
    
    if i % 50 == 0:
        print(i)
            
print('Top 3 interactions: %s' %sorted(interactions, key=lambda inter: inter[2], reverse=True)[:3])

# %%
from sklearn.preprocessing import PolynomialFeatures
for index, degree in enumerate([2,3,4]):
    poly = PolynomialFeatures(degree)
    X_poly_train = poly.fit_transform(X_train)
    reg_poly = linreg.fit(X_poly_train, y_train)
    X_poly_test = poly.transform(X_test)
    y_prediction = reg_poly.predict(X_poly_test)
    print("degree: ", degree, " has r^2 value of ", str(r2_score(y_test, y_prediction)))

# %%
import statsmodels.api as sm
X_int = sm.add_constant(X)
model = sm.OLS(df["price"], X_int).fit()
model.summary()

# %%
def normalize(feature):
    return (feature - feature.mean()) / feature.std()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
linreg = LinearRegression()
linreg.fit(X_train, y_train)

# %%
y_hat_train = linreg.predict(X_train)
y_hat_test = linreg.predict(X_test)
r2_score(y_test, y_hat_test)

# %% [markdown]
# ## Adding Polynomials

# %%
from sklearn.preprocessing import PolynomialFeatures
for index, degree in enumerate([2,3,4]):
    poly = PolynomialFeatures(degree)
    X_poly_train = poly.fit_transform(X_train)
    reg_poly = linreg.fit(X_poly_train, y_train)
    X_poly_test = poly.transform(X_test)
    y_prediction = reg_poly.predict(X_poly_test)
    print("degree: ", degree, " has r^2 value of ", str(r2_score(y_test, y_prediction)))

# %% [markdown]
# ## Adding Interactions

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations

interactions = []
crossvalidation = KFold(n_splits=5, shuffle=True, random_state=1)
feat_combinations = combinations(X.columns, 2)
baseline = 0.2
data = X.copy()
for i, (a, b) in enumerate(feat_combinations):
    data['interaction'] = data[a] * data[b]
    score = np.mean(cross_val_score(linreg, data, y, scoring='r2', cv=crossvalidation))
    if score > baseline:
        interactions.append((a, b, round(score,3)))
    
    if i % 50 == 0:
        print(i)
            
print('Top 3 interactions: %s' %sorted(interactions, key=lambda inter: inter[2], reverse=True)[:3])

# %%
regression = LinearRegression()
crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
final = X.copy()

final['yea'] = final['sqft_living'] * final['sqft_lot']

final_model = np.mean(cross_val_score(regression, final, y, scoring='r2', cv=crossvalidation))

final_model
